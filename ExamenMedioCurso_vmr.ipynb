# %%
#Parte 1: Carga y limpieza

# %%
#se importaran las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#se carga el link
link = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(link)

# %%
#se revisan filas
datos.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#se revisan columnas
datos.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
datos['horsepower'].isnull().sum()
# Out:
# np.int64(6)

# %%
#se calculara la mediana ya que hay valores faltantes
mediana = np.median(datos['horsepower'].dropna())
datos['horsepower'] = datos['horsepower'].fillna(mediana)

# %%
#se crea variable peso potencia
datos['relacion_peso_potencia'] = datos['weight'] / datos['horsepower']

# %%
#Parte 2: Visualización de Datos (Matplotlib)

# %%
#Con este histograma se puede ver mejor la distribucion
plt.hist(df['acceleration'])
plt.title('Distribucion de la aceleracion de los autos')
plt.xlabel('Aceleración')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.scatter(datos['displacement'], datos['horsepower'])
plt.title('Desplazamiento vs Caballos de Fuerza')
plt.xlabel('Displacement')
plt.ylabel('Horsepower')
plt.show()
#Se visualizara el scatter para revisar la relacion

# %%
prome = datos.groupby('origin')['mpg'].mean()

# %%
#Aqui se compara el rendimiento de los carros segun el pais del que vengan
prome.plot(kind='bar')
plt.title('Promedio de MPG por Pais')
plt.xlabel('Origen')
plt.ylabel('MPG')
plt.show()

# %%
#Vanessa Mendoza Ramirez 2120827
